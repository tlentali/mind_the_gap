# %% [markdown]
# ## Prediction
# If the average lifetime of a customer is 90 days since their first deposit :
# build a model to predict the Lifetime Value of a customer given his first 15 days of activity. What other data could be pertinent to answer this question? Given the data provided is the assumption of 90 days valid?

# %%
import pandas as pd
import pandas_profiling
import matplotlib
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.cluster import KMeans

pd.options.display.max_columns = None

matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# get dataset
df_bc = pd.read_csv('data/dataset_betclic.csv')

# convert string date to date
df_bc['BirthDate'] = pd.to_datetime(df_bc['BirthDate'], format='%Y-%m-%dT%H:%M:%S.%fZ')
df_bc['FirstDepositDate'] = pd.to_datetime(df_bc['FirstDepositDate'], format='%Y-%m-%dT%H:%M:%S.%fZ')
df_bc['BetDate'] = pd.to_datetime(df_bc['BetDate'], format='%Y%m%d')

# %% [markdown]
# ## Variables

# %% [markdown]
# ### Lifetime
#
# The lifetime of a customer is the difference between the date of the last bet and the first deposit date
# $max(BetDate) - min(FirstDepositDate)$

# %%
df_max_BetDate = df_bc.groupby(['UserId'])['BetDate'].max().reset_index()
df_max_BetDate.columns = ['UserId', 'max_BetDate']

df_min_FirstDepositDate = df_bc.groupby(['UserId'])['FirstDepositDate'].min().reset_index()
df_min_FirstDepositDate.columns = ['UserId', 'min_FirstDepositDate']

df_ltv = pd.merge(df_bc, 
                  df_max_BetDate, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])

df_ltv = pd.merge(df_ltv, 
                  df_min_FirstDepositDate, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])

df_ltv['lifetime'] = df_ltv['max_BetDate'] - df_ltv['min_FirstDepositDate']

df_ltv.head()
# Out:
#      UserId      Country Gender  BirthDate  PartnerType FirstDepositDate  \
# 0  10783501     Portugal      M 1992-06-08          PPC       2017-01-03
# 1  10782912  Ivory Coast      M 1996-03-18     Internal       2017-01-03
# 2  10780813       France      F 1998-04-05          PPC       2017-01-01
# 3  10783215     Portugal      M 1976-12-17     Internal       2017-01-03
# 4  10783401       Poland      M 1995-04-16  Affiliation       2017-01-03
#
#      BetDate      BetId  Application ProductName  IsLive  BetAmount  \
# 0 2017-01-03  607023702   BETCLIC.PT  SportsBook   False       5.00
# 1 2017-01-03  607023878  BETCLIC.COM  SportsBook   False       5.00
# 2 2017-01-03  607024082   BETCLIC.FR  SportsBook   False       5.00
# 3 2017-01-03  607024088   BETCLIC.PT  SportsBook   False       1.00
# 4 2017-01-03  607024113   EXPEKT.COM  SportsBook   False       5.67
#
#    AmountWon    Odds  Cashout max_BetDate min_FirstDepositDate lifetime
# 0        0.0  124.76      0.0  2017-09-10           2017-01-03 250 days
# 1       23.0    4.60      0.0  2017-10-21           2017-01-03 291 days
# 2        0.0    8.00      0.0  2017-09-04           2017-01-01 246 days
# 3        0.0   41.08      0.0  2017-11-19           2017-01-03 320 days
# 4        0.0    3.75      0.0  2017-01-09           2017-01-03   6 days

# %% [markdown]
# We check if the average lifetime of a customer given by Betclick, 90 jours, is the same in our data :

# %%
df_ltv.drop_duplicates(subset='UserId')['lifetime'].mean()
# Out:
# Timedelta('98 days 01:44:26.035675')

# %% [markdown]
# We find an average at 98 days

# %% [markdown]
# ### Value
#
# I consider the Value of a customer the amount he lost during his active lifetime on Betclic
# $BetAmount - AmountWon$

# %%
df_bet_amount = df_bc.groupby(['UserId'])['BetAmount'].sum().reset_index()
df_bet_amount.columns = ['UserId', 'tot_bet_amount']

df_ltv = pd.merge(df_ltv, 
                  df_bet_amount, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])

df_amount_won = df_bc.groupby(['UserId'])['AmountWon'].sum().reset_index()
df_amount_won.columns = ['UserId', 'tot_amount_won']

df_ltv = pd.merge(df_ltv, 
                  df_amount_won, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])

df_ltv['value_brut'] = df_ltv['tot_bet_amount'] - df_ltv['tot_amount_won']

df_ltv.head()
# Out:
#      UserId      Country Gender  BirthDate  PartnerType FirstDepositDate  \
# 0  10783501     Portugal      M 1992-06-08          PPC       2017-01-03
# 1  10782912  Ivory Coast      M 1996-03-18     Internal       2017-01-03
# 2  10780813       France      F 1998-04-05          PPC       2017-01-01
# 3  10783215     Portugal      M 1976-12-17     Internal       2017-01-03
# 4  10783401       Poland      M 1995-04-16  Affiliation       2017-01-03
#
#      BetDate      BetId  Application ProductName  IsLive  BetAmount  \
# 0 2017-01-03  607023702   BETCLIC.PT  SportsBook   False       5.00
# 1 2017-01-03  607023878  BETCLIC.COM  SportsBook   False       5.00
# 2 2017-01-03  607024082   BETCLIC.FR  SportsBook   False       5.00
# 3 2017-01-03  607024088   BETCLIC.PT  SportsBook   False       1.00
# 4 2017-01-03  607024113   EXPEKT.COM  SportsBook   False       5.67
#
#    AmountWon    Odds  Cashout max_BetDate min_FirstDepositDate lifetime  \
# 0        0.0  124.76      0.0  2017-09-10           2017-01-03 250 days
# 1       23.0    4.60      0.0  2017-10-21           2017-01-03 291 days
# 2        0.0    8.00      0.0  2017-09-04           2017-01-01 246 days
# 3        0.0   41.08      0.0  2017-11-19           2017-01-03 320 days
# 4        0.0    3.75      0.0  2017-01-09           2017-01-03   6 days
#
#    tot_bet_amount  tot_amount_won  value_brut
# 0           30.00            0.00       30.00
# 1         1044.00          900.16      143.84
# 2          966.71          481.26      485.45
# 3          503.30          320.30      183.00
# 4          186.77          169.85       16.92

# %% [markdown]
# ## Lifetime Value
# I consider the lifetime value as :
# $\frac{Value}{Lifetime}$
# I think this value is more interesting than :
# $BetAmount - AmountWon$
# as it allows us to compare two customers independantly of the time spend on the website.

# %%
# value/lifetime
df_ltv['lifetime_int'] = df_ltv['lifetime'].astype('<m8[D]')
# turn 1 the 0 lifetime
df_ltv['lifetime_int'] = np.where(df_ltv['lifetime_int'] == 0, 1, df_ltv['lifetime_int'])
df_ltv['lifetime_value'] = df_ltv['value_brut'] / df_ltv['lifetime_int']

# %%
df_ltv.head()
# Out:
#      UserId      Country Gender  BirthDate  PartnerType FirstDepositDate  \
# 0  10783501     Portugal      M 1992-06-08          PPC       2017-01-03
# 1  10782912  Ivory Coast      M 1996-03-18     Internal       2017-01-03
# 2  10780813       France      F 1998-04-05          PPC       2017-01-01
# 3  10783215     Portugal      M 1976-12-17     Internal       2017-01-03
# 4  10783401       Poland      M 1995-04-16  Affiliation       2017-01-03
#
#      BetDate      BetId  Application ProductName  IsLive  BetAmount  \
# 0 2017-01-03  607023702   BETCLIC.PT  SportsBook   False       5.00
# 1 2017-01-03  607023878  BETCLIC.COM  SportsBook   False       5.00
# 2 2017-01-03  607024082   BETCLIC.FR  SportsBook   False       5.00
# 3 2017-01-03  607024088   BETCLIC.PT  SportsBook   False       1.00
# 4 2017-01-03  607024113   EXPEKT.COM  SportsBook   False       5.67
#
#    AmountWon    Odds  Cashout max_BetDate min_FirstDepositDate lifetime  \
# 0        0.0  124.76      0.0  2017-09-10           2017-01-03 250 days
# 1       23.0    4.60      0.0  2017-10-21           2017-01-03 291 days
# 2        0.0    8.00      0.0  2017-09-04           2017-01-01 246 days
# 3        0.0   41.08      0.0  2017-11-19           2017-01-03 320 days
# 4        0.0    3.75      0.0  2017-01-09           2017-01-03   6 days
#
#    tot_bet_amount  tot_amount_won  value_brut  lifetime_int  lifetime_value
# 0           30.00            0.00       30.00         250.0        0.120000
# 1         1044.00          900.16      143.84         291.0        0.494296
# 2          966.71          481.26      485.45         246.0        1.973374
# 3          503.30          320.30      183.00         320.0        0.571875
# 4          186.77          169.85       16.92           6.0        2.820000

# %%
# age
now = pd.Timestamp(datetime.now())
df_ltv['age'] = (now - df_bc['BirthDate']).astype('<m8[Y]')

# %% [markdown]
# ## 15 jours

# %%
df_ltv_15 = df_ltv[df_ltv['BetDate'] <= (df_ltv['FirstDepositDate'] + timedelta(days=15))]

# %% [markdown]
# ### Building feature

# %% [markdown]
# #### Features on bets

# %%
mean_bet_by_user = df_ltv_15.groupby('UserId')['BetAmount'].mean().reset_index()
mean_bet_by_user.columns = ['UserId', 'mean_bet']

min_bet_by_user = df_ltv_15.groupby('UserId')['BetAmount'].min().reset_index()
min_bet_by_user.columns = ['UserId', 'min_bet']

max_bet_by_user = df_ltv_15.groupby('UserId')['BetAmount'].max().reset_index()
max_bet_by_user.columns = ['UserId', 'max_bet']

median_bet_by_user = df_ltv_15.groupby('UserId')['BetAmount'].median().reset_index()
median_bet_by_user.columns = ['UserId', 'median_bet']

sum_bet_by_user = df_ltv_15.groupby('UserId')['BetAmount'].sum().reset_index()
sum_bet_by_user.columns = ['UserId', 'sum_bet']

count_bet_by_user = df_ltv_15.groupby('UserId')['BetId'].count().reset_index()
count_bet_by_user.columns = ['UserId', 'count_bet']

# %% [markdown]
# #### Feature on bet won

# %%
mean_bet_won_by_user = df_ltv_15.groupby('UserId')['AmountWon'].mean().reset_index()
mean_bet_won_by_user.columns = ['UserId', 'mean_bet_won']

min_bet_won_by_user = df_ltv_15.groupby('UserId')['AmountWon'].min().reset_index()
min_bet_won_by_user.columns = ['UserId', 'min_bet_won']

max_bet_won_by_user = df_ltv_15.groupby('UserId')['AmountWon'].max().reset_index()
max_bet_won_by_user.columns = ['UserId', 'max_bet_won']

median_bet_won_by_user = df_ltv_15.groupby('UserId')['AmountWon'].median().reset_index()
median_bet_won_by_user.columns = ['UserId', 'median_bet_won']

sum_bet_won_by_user = df_ltv_15.groupby('UserId')['AmountWon'].sum().reset_index()
sum_bet_won_by_user.columns = ['UserId', 'sum_bet_won']

count_bet_won_by_user = df_ltv_15[df_ltv_15['AmountWon']>0].groupby('UserId')['BetId'].count().reset_index()
count_bet_won_by_user.columns = ['UserId', 'count_bet_won']

# %% [markdown]
# #### Other feature

# %%
mean_ods_by_user = df_ltv_15.groupby('UserId')['Odds'].mean()

# %%
islive_by_user = df_ltv_15.groupby('UserId')['IsLive'].max()

# %% [markdown]
# #### Categorical features

# %%
application_used = pd.get_dummies(df_ltv_15[['UserId', 'Application']]).groupby('UserId').sum()

partnertype_used = pd.get_dummies(df_ltv_15[['UserId', 'PartnerType']]).groupby('UserId').sum()

gender_used = pd.get_dummies(df_ltv_15[['UserId', 'Gender']]).groupby('UserId').sum()
gender_used = gender_used / gender_used
gender_used = gender_used.fillna(0)

Country_used = pd.get_dummies(df_ltv_15[['UserId', 'Country']]).groupby('UserId').sum()
Country_used = Country_used / Country_used
Country_used = Country_used.fillna(0)

# %% [markdown]
# ### Merging all features

# %%
df_res = pd.merge(mean_bet_by_user, 
                  min_bet_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  max_bet_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  median_bet_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  sum_bet_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  count_bet_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  mean_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  min_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  max_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  median_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  sum_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  count_bet_won_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  application_used, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  mean_ods_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  islive_by_user, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  partnertype_used, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  gender_used, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])
df_res = pd.merge(df_res, 
                  Country_used, 
                  how='left', 
                  left_on=['UserId'], 
                  right_on=['UserId'])

# %% [markdown]
# #### Adding interesting feature

# %%
df_res['ratio_win'] = df_res['count_bet_won'] / df_res['count_bet']

# %% [markdown]
# ### Final cleaning

# %%
df_res = df_res.fillna(0)

# %%
ltv_age = df_ltv[['UserId', 'age']].drop_duplicates()

# %%
df_final = pd.merge(df_res, 
                    ltv_age, 
                    how='left', 
                    left_on=['UserId'], 
                    right_on=['UserId'])

# %%
ltv_to_evaluation = df_ltv[['UserId', 'lifetime_value']].drop_duplicates()

# %%
df_final = pd.merge(df_res, 
                    ltv_to_evaluation, 
                    how='left', 
                    left_on=['UserId'], 
                    right_on=['UserId'])

# %% [markdown]
# #### Saving the dataset

# %%
df_final.to_csv('15_bc.csv', index=None, sep=';')

# %% [markdown]
# # Clustering
# N'etant pas satisfait de l'approche du probleme en regression (code dans le notebook regression.ipynb), je propose une autre facon de voir les choses.
# En clusterisant les comportements, nous obtenons une vision des differents profils des clients et ainsi observer les differences de lifetime value de chaque groupe.
# Le choix de 5 classes est arbitraire (ouvert à discussion et à une analyse plus poussée).

# %% [markdown]
# ## Kmeans #1

# %%
# compute kmeans
RANDOM_STATE = 50
NB_CLUSTERS = 5
X = df_final[list(set(df_final).difference({'UserId'}))]
kmeans = KMeans(n_clusters=NB_CLUSTERS,
                random_state=RANDOM_STATE, n_jobs=8)
kmeans.fit(X)
X['kmeans_cluster'] = kmeans.labels_

# %%
from matplotlib import colors as matplot_colors
import matplotlib.pyplot as plt

def background_gradient(row):
    cmap = 'YlGnBu'
    m = row.min()
    M = row.max()
    low = 0
    high = 0.2
    rng = M - m
    norm = matplot_colors.Normalize(m - (rng * low), M + (rng * high))
    normed = norm(list(row))
    c = [matplot_colors.rgb2hex(x) for x in plt.cm.get_cmap(cmap)(normed)]
    return ['background-color: %s' % color for color in c]


X.groupby('kmeans_cluster').mean().T.style.apply(background_gradient, axis=1)
# Out:
# <style  type="text/css" >
#     #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row0_col0 {
#             background-color:  #fafdce;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row0_col1 {
#             background-color:  #e2f4b2;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row0_col2 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row0_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row0_col4 {
#             background-color:  #fdfed4;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row1_col0 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row1_col1 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row1_col2 {
#             background-color:  #1f80b8;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row1_col3 {
#             background-color:  #f4fbc0;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row1_col4 {
#             background-color:  #fafdcf;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row2_col0 {
#             background-color:  #1e83ba;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row2_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row2_col2 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row2_col3 {
#             background-color:  #1e86bb;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row2_col4 {
#             background-color:  #2075b3;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row3_col0 {
#             background-color:  #9ed9b8;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row3_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row3_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row3_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row3_col4 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row4_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row4_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row4_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row4_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row4_col4 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row5_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row5_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row5_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row5_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row5_col4 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row6_col0 {
#             background-color:  #a5dcb7;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row6_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row6_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row6_col3 {
#             background-color:  #1f80b8;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row6_col4 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row7_col0 {
#             background-color:  #2350a1;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row7_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row7_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row7_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row7_col4 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row8_col0 {
#             background-color:  #1f7eb7;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row8_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row8_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row8_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row8_col4 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row9_col0 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row9_col1 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row9_col2 {
#             background-color:  #d1edb3;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row9_col3 {
#             background-color:  #f7fcc7;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row9_col4 {
#             background-color:  #feffd6;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row10_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row10_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row10_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row10_col3 {
#             background-color:  #78cbbc;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row10_col4 {
#             background-color:  #61c2bf;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row11_col0 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row11_col1 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row11_col2 {
#             background-color:  #2075b3;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row11_col3 {
#             background-color:  #eff9b5;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row11_col4 {
#             background-color:  #f9fdcc;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row12_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row12_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row12_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row12_col3 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row12_col4 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row13_col0 {
#             background-color:  #e0f3b2;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row13_col1 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row13_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row13_col3 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row13_col4 {
#             background-color:  #6dc6be;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row14_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row14_col1 {
#             background-color:  #fdfed4;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row14_col2 {
#             background-color:  #ffffd9;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row14_col3 {
#             background-color:  #a5dcb7;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row14_col4 {
#             background-color:  #8cd2ba;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4row15_col0 {
#             background-color:  #24419a;
#         }    #T_34d94ccc_2df7_11e9_a183_100ba9ef6ed4r

# %%
X.groupby('kmeans_cluster').count()
# Out:
#                 min_bet  median_bet  Country_France  Country_Netherlands  \
# kmeans_cluster
# 0                 23544       23544           23544                23544
# 1                     1           1               1                    1
# 2                     3           3               3                    3
# 3                    46          46              46                   46
# 4                   436         436             436                  436
#
#                 PartnerType_Ad Networks  PartnerType_Sponsoring  \
# kmeans_cluster
# 0                                 23544                   23544
# 1                                     1                       1
# 2                                     3                       3
# 3                                    46                      46
# 4                                   436                     436
#
#                 Application_BETCLIC.PT  min_bet_won  Country_Hungary  \
# kmeans_cluster
# 0                                23544        23544            23544
# 1                                    1            1                1
# 2                                    3            3                3
# 3                                   46           46               46
# 4                                  436          436              436
#
#                 sum_bet_won  Gender_F  mean_bet  PartnerType_Expekt  \
# kmeans_cluster
# 0                     23544     23544     23544               23544
# 1                         1         1         1                   1
# 2                         3         3         3                   3
# 3                        46        46        46                  46
# 4                       436       436       436                 436
#
#                 Country_United Kingdom    Odds  Country_Portugal  \
# kmeans_cluster
# 0                                 23544  23544             23544
# 1                                     1      1                 1
# 2                                     3      3                 3
# 3                                    46     46                46
# 4                                   436    436               436
#
#                 PartnerType_Referral  lifetime_value  PartnerType_betclic  \
# kmeans_cluster
# 0                              23544           23544                23544
# 1                                  1               1                    1
# 2                                  3               3                    3
# 3                                 46              46                   46
# 4                                436             436                  436
#
#                 Country_Norway  mean_bet_won  count_bet  PartnerType_Emailing  \
# kmeans_cluster
# 0                        23544         23544      23544                 23544
# 1                            1             1          1                     1
# 2                            3             3          3                     3
# 3                           46            46         46                    46
# 4                          436           436        436                   436
#
#                 Country_Italy  ratio_win  Country_Ivory Coast  \
# kmeans_cluster
# 0                       23544      23544                23544
# 1                           1          1                    1
# 2                           3          3                    3
# 3                          46         46                   46
# 4                         436        436                  436
#
#                 PartnerType_Affiliation  Application_BETCLIC.COM  \
# kmeans_cluster
# 0                                 23544                    23544
# 1                                     1                        1
# 2                                     3                        3
# 3                                    46                       46
# 4                                   436                      436
#
#                 Application_BETCLIC.IT  max_bet_won  max_bet  \
# kmeans_cluster
# 0                                23544        23544    23544
# 1                                    1            1        1
# 2                                    3            3        3
# 3                                   46           46       46
# 4                                  436          436      436
#
#                 Application_BETCLIC.FR  sum_bet  Country_Finland   \
# kmeans_cluster
# 0                                23544    23544             23544
# 1                                    1        1                 1
# 2                                    3        3                 3
# 3                                   46       46                46
# 4                                  436      436               436
#
#                 Country_Sweden  PartnerType_Offline  PartnerType_SEO  \
# kmeans_cluster
# 0                        23544                23544            23544
# 1                            1                    1                1
# 2                            3                    3                3
# 3                           46                   46               46
# 4                          436                  436              436
#
#                 Country_Germany  Country_Poland  IsLive  PartnerType_Mobile  \
# kmeans_cluster
# 0                         23544           23544   23544               23544
# 1                             1               1       1                   1
# 2                             3               3       3                   3
# 3                            46              46      46                  46
# 4                           436             436     436                 436
#
#                 PartnerType_PPC  Gender_M  count_bet_won  Country_Switzerland  \
# kmeans_cluster
# 0                         23544     23544          23544                23544
# 1                             1         1              1                    1
# 2                             3         3              3                    3
# 3                            46        46             46                   46
# 4                           436       436            436                  436
#
#                 PartnerType_Partnerships  PartnerType_Internal  \
# kmeans_cluster
# 0                                  23544                 23544
# 1                                      1                     1
# 2                                      3                     3
# 3                                     46                    46
# 4                                    436                   436
#
#                 Application_EXPEKT.COM  median_bet_won
# kmeans_cluster
# 0                                23544           23544
# 1                                    1               1
# 2                                    3               3
# 3                                   46              46
# 4                                  436             436

# %% [markdown]
# ### Conclusion Kmeans #1
# Les clusters sont beaucoup trop desequilibrés, les valeurs 'financieres' comportent des cas extremes qui polluent le bon placement des centroides.

# %% [markdown]
# ## Kmeans #2 : Robust scaler

# %%
X = df_final[list(set(df_final).difference({'UserId'}))]

transformer = RobustScaler().fit(X)
df_robust = pd.DataFrame(transformer.transform(X))
df_robust.columns = X.columns
df_robust#['mean_bet'].hist()

# compute kmeans
RANDOM_STATE = 50
NB_CLUSTERS = 5
X = df_robust[list(set(df_robust).difference({'UserId'}))]
kmeans = KMeans(n_clusters=NB_CLUSTERS,
                random_state=RANDOM_STATE, n_jobs=8)
kmeans.fit(X)
X['kmeans_cluster'] = kmeans.labels_
X.groupby('kmeans_cluster').mean().T.style.apply(background_gradient, axis=1)
# Out:
# <style  type="text/css" >
#     #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row0_col0 {
#             background-color:  #f1fabb;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row0_col1 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row0_col2 {
#             background-color:  #3fb4c4;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row0_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row0_col4 {
#             background-color:  #bbe4b5;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row1_col0 {
#             background-color:  #f0f9b8;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row1_col1 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row1_col2 {
#             background-color:  #53bdc1;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row1_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row1_col4 {
#             background-color:  #cfecb3;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row2_col0 {
#             background-color:  #2397c1;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row2_col1 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row2_col2 {
#             background-color:  #2351a2;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row2_col3 {
#             background-color:  #2da2c2;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row2_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row3_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row3_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row3_col2 {
#             background-color:  #1d8ebf;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row3_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row3_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row4_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row4_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row4_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row4_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row4_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row5_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row5_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row5_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row5_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row5_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row6_col0 {
#             background-color:  #1e8abd;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row6_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row6_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row6_col3 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row6_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row7_col0 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row7_col1 {
#             background-color:  #e8f6b1;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row7_col2 {
#             background-color:  #f9fdcb;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row7_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row7_col4 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row8_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row8_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row8_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row8_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row8_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row9_col0 {
#             background-color:  #fcfed1;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row9_col1 {
#             background-color:  #c0e6b5;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row9_col2 {
#             background-color:  #f3fabd;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row9_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row9_col4 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row10_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row10_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row10_col2 {
#             background-color:  #fafdce;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row10_col3 {
#             background-color:  #bde5b5;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row10_col4 {
#             background-color:  #65c3bf;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row11_col0 {
#             background-color:  #8ed3ba;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row11_col1 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row11_col2 {
#             background-color:  #1e88bc;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row11_col3 {
#             background-color:  #e0f3b2;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row11_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row12_col0 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row12_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row12_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row12_col3 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row12_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row13_col0 {
#             background-color:  #feffd8;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row13_col1 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row13_col2 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row13_col3 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row13_col4 {
#             background-color:  #feffd6;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row14_col0 {
#             background-color:  #50bbc2;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row14_col1 {
#             background-color:  #fafdce;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row14_col2 {
#             background-color:  #feffd8;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row14_col3 {
#             background-color:  #24419a;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row14_col4 {
#             background-color:  #ffffd9;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4row15_col0 {
#             background-color:  #24449c;
#         }    #T_6625053c_2df7_11e9_a183_100ba9ef6ed4r

# %%
X.groupby('kmeans_cluster').count()
# Out:
#                 min_bet  median_bet  Country_France  Country_Netherlands  \
# kmeans_cluster
# 0                 23156       23156           23156                23156
# 1                    71          71              71                   71
# 2                   712         712             712                  712
# 3                    90          90              90                   90
# 4                     1           1               1                    1
#
#                 PartnerType_Ad Networks  PartnerType_Sponsoring  \
# kmeans_cluster
# 0                                 23156                   23156
# 1                                    71                      71
# 2                                   712                     712
# 3                                    90                      90
# 4                                     1                       1
#
#                 Application_BETCLIC.PT  min_bet_won  Country_Hungary  \
# kmeans_cluster
# 0                                23156        23156            23156
# 1                                   71           71               71
# 2                                  712          712              712
# 3                                   90           90               90
# 4                                    1            1                1
#
#                 sum_bet_won  Application_EXPEKT.COM  Gender_F  \
# kmeans_cluster
# 0                     23156                   23156     23156
# 1                        71                      71        71
# 2                       712                     712       712
# 3                        90                      90        90
# 4                         1                       1         1
#
#                 PartnerType_Expekt   Odds  Country_Portugal  \
# kmeans_cluster
# 0                            23156  23156             23156
# 1                               71     71                71
# 2                              712    712               712
# 3                               90     90                90
# 4                                1      1                 1
#
#                 PartnerType_Referral  lifetime_value  PartnerType_betclic  \
# kmeans_cluster
# 0                              23156           23156                23156
# 1                                 71              71                   71
# 2                                712             712                  712
# 3                                 90              90                   90
# 4                                  1               1                    1
#
#                 Country_Norway  mean_bet_won  count_bet  PartnerType_Emailing  \
# kmeans_cluster
# 0                        23156         23156      23156                 23156
# 1                           71            71         71                    71
# 2                          712           712        712                   712
# 3                           90            90         90                    90
# 4                            1             1          1                     1
#
#                 Country_Italy  ratio_win  Country_Ivory Coast  \
# kmeans_cluster
# 0                       23156      23156                23156
# 1                          71         71                   71
# 2                         712        712                  712
# 3                          90         90                   90
# 4                           1          1                    1
#
#                 PartnerType_Affiliation  median_bet_won  \
# kmeans_cluster
# 0                                 23156           23156
# 1                                    71              71
# 2                                   712             712
# 3                                    90              90
# 4                                     1               1
#
#                 Application_BETCLIC.COM  Application_BETCLIC.IT  max_bet_won  \
# kmeans_cluster
# 0                                 23156                   23156        23156
# 1                                    71                      71           71
# 2                                   712                     712          712
# 3                                    90                      90           90
# 4                                     1                       1            1
#
#                 max_bet  Application_BETCLIC.FR  sum_bet  Country_Finland   \
# kmeans_cluster
# 0                 23156                   23156    23156             23156
# 1                    71                      71       71                71
# 2                   712                     712      712               712
# 3                    90                      90       90                90
# 4                     1                       1        1                 1
#
#                 Country_Sweden  PartnerType_Offline  PartnerType_SEO  \
# kmeans_cluster
# 0                        23156                23156            23156
# 1                           71                   71               71
# 2                          712                  712              712
# 3                           90                   90               90
# 4                            1                    1                1
#
#                 Country_Germany  Country_Poland  IsLive  PartnerType_Mobile  \
# kmeans_cluster
# 0                         23156           23156   23156               23156
# 1                            71              71      71                  71
# 2                           712             712     712                 712
# 3                            90              90      90                  90
# 4                             1               1       1                   1
#
#                 PartnerType_PPC  Gender_M  count_bet_won  Country_Switzerland  \
# kmeans_cluster
# 0                         23156     23156          23156                23156
# 1                            71        71             71                   71
# 2                           712       712            712                  712
# 3                            90        90             90                   90
# 4                             1         1              1                    1
#
#                 PartnerType_Partnerships  PartnerType_Internal  mean_bet  \
# kmeans_cluster
# 0                                  23156                 23156     23156
# 1                                     71                    71        71
# 2                                    712                   712       712
# 3                                     90                    90        90
# 4                                      1                     1         1
#
#                 Country_United Kingdom
# kmeans_cluster
# 0                                 23156
# 1                                    71
# 2                                   712
# 3                                    90
# 4                                     1

# %% [markdown]
# ### Conlusion Kmeans #2
# Amelioration du kmeans #1 mais toujours aussi desequilibré, essayons avec un scaler plus classique.

# %% [markdown]
# ## Kmeans #3

# %%
X = df_final[list(set(df_final).difference({'UserId'}))]

transformer = MinMaxScaler().fit(X)
df_robust = pd.DataFrame(transformer.transform(X))
df_robust.columns = X.columns
df_robust#['mean_bet'].hist()

# compute kmeans
RANDOM_STATE = 50
NB_CLUSTERS = 5
X = df_robust[list(set(df_robust).difference({'UserId'}))]
kmeans = KMeans(n_clusters=NB_CLUSTERS,
                random_state=RANDOM_STATE, n_jobs=8)
kmeans.fit(X)
df_final['kmeans_cluster'] = kmeans.labels_
df_final.groupby('kmeans_cluster').mean().T.style.apply(background_gradient, axis=1)
# Out:
# /home/tom/source/smart_click/betclic/lib/python3.5/site-packages/sklearn/preprocessing/data.py:323: DataConversionWarning: Data with input dtype bool, int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# <style  type="text/css" >
#     #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row0_col0 {
#             background-color:  #9cd8b8;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row0_col1 {
#             background-color:  #57bec1;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row0_col2 {
#             background-color:  #1d90c0;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row0_col3 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row0_col4 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row1_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row1_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row1_col2 {
#             background-color:  #97d6b9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row1_col3 {
#             background-color:  #f1faba;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row1_col4 {
#             background-color:  #206eb0;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row2_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row2_col1 {
#             background-color:  #feffd8;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row2_col2 {
#             background-color:  #7cccbb;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row2_col3 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row2_col4 {
#             background-color:  #216aad;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row3_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row3_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row3_col2 {
#             background-color:  #cdebb4;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row3_col3 {
#             background-color:  #206eb0;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row3_col4 {
#             background-color:  #2166ac;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row4_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row4_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row4_col2 {
#             background-color:  #92d5b9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row4_col3 {
#             background-color:  #f8fcc9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row4_col4 {
#             background-color:  #206eb0;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row5_col0 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row5_col1 {
#             background-color:  #3bb0c3;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row5_col2 {
#             background-color:  #d9f0b3;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row5_col3 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row5_col4 {
#             background-color:  #e7f6b1;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row6_col0 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row6_col1 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row6_col2 {
#             background-color:  #dcf1b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row6_col3 {
#             background-color:  #2073b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row6_col4 {
#             background-color:  #d0edb3;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row7_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row7_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row7_col2 {
#             background-color:  #69c5be;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row7_col3 {
#             background-color:  #f3fabd;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row7_col4 {
#             background-color:  #2259a6;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row8_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row8_col1 {
#             background-color:  #feffd8;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row8_col2 {
#             background-color:  #7cccbb;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row8_col3 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row8_col4 {
#             background-color:  #225ca7;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row9_col0 {
#             background-color:  #b0e0b6;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row9_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row9_col2 {
#             background-color:  #fdfed4;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row9_col3 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row9_col4 {
#             background-color:  #6dc6be;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row10_col0 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row10_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row10_col2 {
#             background-color:  #5dc0c0;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row10_col3 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row10_col4 {
#             background-color:  #225da8;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row11_col0 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row11_col1 {
#             background-color:  #39adc3;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row11_col2 {
#             background-color:  #b4e2b6;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row11_col3 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row11_col4 {
#             background-color:  #e1f3b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row12_col0 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row12_col1 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row12_col2 {
#             background-color:  #a9ddb7;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row12_col3 {
#             background-color:  #24459c;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row12_col4 {
#             background-color:  #c4e8b4;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row13_col0 {
#             background-color:  #eef8b3;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row13_col1 {
#             background-color:  #2073b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row13_col2 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row13_col3 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row13_col4 {
#             background-color:  #cdebb4;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row14_col0 {
#             background-color:  #edf8b1;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row14_col1 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row14_col2 {
#             background-color:  #ffffd9;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row14_col3 {
#             background-color:  #24419a;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row14_col4 {
#             background-color:  #dff2b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4row15_col0 {
#             background-color:  #dcf1b2;
#         }    #T_35d0ed1b_2df7_11e9_a183_100ba9ef6ed4r

# %%
df_final.groupby('kmeans_cluster').count()['UserId']
# Out:
# kmeans_cluster
# 0    6945
# 1    5386
# 2    2917
# 3    5441
# 4    3341
# Name: UserId, dtype: int64

# %% [markdown]
# ### Conclusion kmeans #3
# Les clusters sont bien equilibrés et il est possible de raconter une histoire sur le cluster ayant une plus forte lifetime value:
# Les clients generant un $\text{lifetime value}$ haut parient des montants elevés en moyenne, jouent assez peu souvant, sont des femmes, francaise/italienne, sur des Odds assez bas, rarement en live et ont un assez bon ratio de gain.
#
#
# Un tel modèle permet de predire, suivant les actions effectuées par le client en 15 jours, potentiel $\text{lifetime value}$ d'un client.

# %% [markdown]
# Un tel model est sujet a etre amelioré mais cette piste peut servir de base solide pour la suite.
# En temps normal j'utilise la librairie "pickle" pour sauvegarder mes modeles mais pour ne pas generer de fichier suplementaire sur vos machines, j'ai retiré toute sauvegarde.
# Tous les modeles ont une seed fixe pour etre reproductible.
